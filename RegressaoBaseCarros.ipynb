# %%
import pandas as pd
import tensorflow as tf
import sklearn

# %%
pd.__version__,tf.__version__,sklearn.__version__
# Out:
# ('2.2.3', '2.16.1', '1.5.2')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
base = pd.read_csv('C:/Users/nanojau/OneDrive/Documentos/CURSOS/DeepLearningWithPythonUdemy/autos.csv',encoding='ISO-8859-1')
base
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 0         manuell        0         golf     150000                    0
# 1         manuell      190          NaN     125000                    5
# 2       automatik      163        grand     125000                    8
# 3         manuell       75         golf     150000                    6
# 4         manuell       69        fabia      90000                    7
# ...           ...      ...          ...        ...                  ...
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage          dateCreated  \
# 0        benzin      volkswagen               NaN  2016-03-24 00:00:00
# 1        diesel            audi                ja  2016-03-24 00:00:00
# 2        diesel            jeep               NaN  2016-03-14 00:00:00
# 3        benzin      volkswagen              nein  2016-03-17 00:00:00
# 4        diesel           skoda              nein  2016-03-31 00:00:00
# ...         ...             ...               ...                  ...
# 371523      NaN  sonstige_autos               NaN  2016-03-14 00:00:00
# 371524   benzin           smart              nein  2016-03-05 00:00:00
# 371525   diesel      volkswagen              nein  2016-03-19 00:00:00
# 371526   diesel      volkswagen               NaN  2016-03-20 00:00:00
# 371527   benzin             bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 0                  0       70435  2016-04-07 03:16:57
# 1                  0       66954  2016-04-07 01:46:50
# 2                  0       90480  2016-04-05 12:47:46
# 3                  0       91074  2016-03-17 17:40:17
# 4                  0       60437  2016-04-06 10:17:21
# ...              ...         ...                  ...
# 371523             0       39576  2016-04-06 00:46:52
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371526             0       40764  2016-03-24 12:45:21
# 371527             0       73326  2016-03-22 03:17:10
#
# [371528 rows x 20 columns]

# %%
base = base.drop('dateCrawled', axis = 1)
base = base.drop('dateCreated', axis = 1)
base = base.drop('nrOfPictures', axis = 1)
base = base.drop('postalCode', axis = 1)
base = base.drop('lastSeen', axis = 1)
base
# Out:
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...                                              ...     ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze  privat   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps  privat   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI  privat   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 1          test       coupe                2011    manuell      190
# 2          test         suv                2004  automatik      163
# 3          test  kleinwagen                2001    manuell       75
# 4          test  kleinwagen                2008    manuell       69
# ...         ...         ...                 ...        ...      ...
# 371523     test         NaN                2005        NaN        0
# 371524     test      cabrio                2000  automatik      101
# 371525     test         bus                1996    manuell      102
# 371526     test       kombi                2002    manuell      100
# 371527  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1               NaN     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523          NaN      20000                    1      NaN  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 15 columns]

# %%
base['name'].value_counts()
# Out:
# name
# Ford_Fiesta                                              657
# BMW_318i                                                 627
# Opel_Corsa                                               622
# Volkswagen_Golf_1.4                                      603
# BMW_316i                                                 523
#                                                         ...
# Audi_A4_Avant_Klima_Gruene_Plakette_TÜV_&AU_NEU_XENON      1
# Renault_clio_in_gold_450VB_!!                              1
# Fiat_Doblo_1.6_Multijet                                    1
# Renault_Laguna_1                                           1
# BMW_M135i_vollausgestattet_NP_52.720____Euro               1
# Name: count, Length: 233531, dtype: int64

# %%
base.drop('name', axis = 1)
# Out:
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 0         manuell        0         golf     150000                    0
# 1         manuell      190          NaN     125000                    5
# 2       automatik      163        grand     125000                    8
# 3         manuell       75         golf     150000                    6
# 4         manuell       69        fabia      90000                    7
# ...           ...      ...          ...        ...                  ...
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage
# 0        benzin      volkswagen               NaN
# 1        diesel            audi                ja
# 2        diesel            jeep               NaN
# 3        benzin      volkswagen              nein
# 4        diesel           skoda              nein
# ...         ...             ...               ...
# 371523      NaN  sonstige_autos               NaN
# 371524   benzin           smart              nein
# 371525   diesel      volkswagen              nein
# 371526   diesel      volkswagen               NaN
# 371527   benzin             bmw              nein
#
# [371528 rows x 14 columns]

# %%
base['seller'].value_counts()
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %%
base.drop('seller', axis = 1)
# Out:
#                                                 name offerType  price  \
# 0                                         Golf_3_1.6   Angebot    480
# 1                               A5_Sportback_2.7_Tdi   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic   Angebot   3600
# ...                                              ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro   Angebot  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 1          test       coupe                2011    manuell      190
# 2          test         suv                2004  automatik      163
# 3          test  kleinwagen                2001    manuell       75
# 4          test  kleinwagen                2008    manuell       69
# ...         ...         ...                 ...        ...      ...
# 371523     test         NaN                2005        NaN        0
# 371524     test      cabrio                2000  automatik      101
# 371525     test         bus                1996    manuell      102
# 371526     test       kombi                2002    manuell      100
# 371527  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1               NaN     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523          NaN      20000                    1      NaN  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 14 columns]

# %%
base['offerType'].value_counts()
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %%
base.drop('offerType', axis = 1)
# Out:
#                                                 name  seller  price   abtest  \
# 0                                         Golf_3_1.6  privat    480     test
# 1                               A5_Sportback_2.7_Tdi  privat  18300     test
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   9800     test
# 3                                 GOLF_4_1_4__3TÜRER  privat   1500     test
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   3600     test
# ...                                              ...     ...    ...      ...
# 371523                    Suche_t4___vito_ab_6_sitze  privat   2200     test
# 371524         Smart_smart_leistungssteigerung_100ps  privat   1199     test
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   9200     test
# 371526                        VW_Golf_Kombi_1_9l_TDI  privat   3400     test
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro  privat  28990  control
#
#        vehicleType  yearOfRegistration    gearbox  powerPS        model  \
# 0              NaN                1993    manuell        0         golf
# 1            coupe                2011    manuell      190          NaN
# 2              suv                2004  automatik      163        grand
# 3       kleinwagen                2001    manuell       75         golf
# 4       kleinwagen                2008    manuell       69        fabia
# ...            ...                 ...        ...      ...          ...
# 371523         NaN                2005        NaN        0          NaN
# 371524      cabrio                2000  automatik      101       fortwo
# 371525         bus                1996    manuell      102  transporter
# 371526       kombi                2002    manuell      100         golf
# 371527   limousine                2013    manuell      320      m_reihe
#
#         kilometer  monthOfRegistration fuelType           brand  \
# 0          150000                    0   benzin      volkswagen
# 1          125000                    5   diesel            audi
# 2          125000                    8   diesel            jeep
# 3          150000                    6   benzin      volkswagen
# 4           90000                    7   diesel           skoda
# ...           ...                  ...      ...             ...
# 371523      20000                    1      NaN  sonstige_autos
# 371524     125000                    3   benzin           smart
# 371525     150000                    3   diesel      volkswagen
# 371526     150000                    6   diesel      volkswagen
# 371527      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 14 columns]

# %%
base
# Out:
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...                                              ...     ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze  privat   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps  privat   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI  privat   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 1          test       coupe                2011    manuell      190
# 2          test         suv                2004  automatik      163
# 3          test  kleinwagen                2001    manuell       75
# 4          test  kleinwagen                2008    manuell       69
# ...         ...         ...                 ...        ...      ...
# 371523     test         NaN                2005        NaN        0
# 371524     test      cabrio                2000  automatik      101
# 371525     test         bus                1996    manuell      102
# 371526     test       kombi                2002    manuell      100
# 371527  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1               NaN     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523          NaN      20000                    1      NaN  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 15 columns]

# %%
base.loc[base['price'] <=10]
# Out:
#                                                      name  seller offerType  \
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# 40                      Suche_Opel_corsa_a_zu_verschenken  privat   Angebot
# 60      TAUSCHE_BMW_E38_740i_g._SUV_/_GELÄNDEWAGEN_LES...  privat   Angebot
# 91      MERCEDES_BENZ_W124_250D_83KW_/_113PS___SCHLACH...  privat   Angebot
# 115                                       Golf_IV_1.4_16V  privat   Angebot
# ...                                                   ...     ...       ...
# 371356          Verkaufen_einen_Opel_corsa_b_worlcup_cool  privat   Angebot
# 371392   Ford_Fiesta_1.3___60PS___Bj_2002___Klima___Servo  privat   Angebot
# 371402                          Suzuki_Swift_zu_verkaufen  privat   Angebot
# 371431                                         Seat_Arosa  privat   Angebot
# 371522                                    Mitsubishi_Cold  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 7           0     test   limousine                1980  manuell       50
# 40          0     test         NaN                1990      NaN        0
# 60          1  control         suv                1994  manuell      286
# 91          1  control   limousine                1995  manuell      113
# 115         0     test         NaN                2017  manuell        0
# ...       ...      ...         ...                 ...      ...      ...
# 371356      0  control         NaN                2000  manuell       65
# 371392      0     test  kleinwagen                2002  manuell       60
# 371402      0  control  kleinwagen                1999  manuell       53
# 371431      0  control  kleinwagen                1999  manuell       37
# 371522      0  control         NaN                2005  manuell        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 7         andere      40000                    7   benzin      volkswagen
# 40         corsa     150000                    1   benzin            opel
# 60           NaN     150000                   11      NaN  sonstige_autos
# 91      e_klasse     150000                    4   diesel   mercedes_benz
# 115         golf       5000                   12   benzin      volkswagen
# ...          ...        ...                  ...      ...             ...
# 371356     corsa     150000                    0      NaN            opel
# 371392    fiesta     150000                    3   benzin            ford
# 371402     swift     150000                    3   benzin          suzuki
# 371431     arosa     150000                    7   benzin            seat
# 371522      colt     150000                    7   benzin      mitsubishi
#
#        notRepairedDamage
# 7                   nein
# 40                   NaN
# 60                   NaN
# 91                  nein
# 115                  NaN
# ...                  ...
# 371356                ja
# 371392               NaN
# 371402               NaN
# 371431                ja
# 371522                ja
#
# [12118 rows x 15 columns]

# %%
base['price'].mean()
# Out:
# 17295.14186548524

# %%
base = base[base['price'] > 10]

# %%
base.shape
# Out:
# (359410, 15)

# %%
base.loc[base['price'] > 35000]
# Out:
#                                                      name  seller offerType  \
# 56                                   BMW_435i_Sport_coupe  privat   Angebot
# 148     Mercedes_Benz_GLK_250_BlueTEC_4Matic_Standhzg_...  privat   Angebot
# 275           Audi_A6_3.0_TDI_competition_S_Line_LED_BOSE  privat   Angebot
# 277            Mercedes_Benz_CLS_350_CDI_4Matic_7G_TRONIC  privat   Angebot
# 376                                          Corvette_Z06  privat   Angebot
# ...                                                   ...     ...       ...
# 371039                Mercedes_Benz_E_500_Coupe_7G_TRONIC  privat   Angebot
# 371196  Cadillac_CTS_V_Dt.Modell_Garantie_3/17_Magnafl...  privat   Angebot
# 371255  Land_Rover_Defender_110_DPF_SW_Heritage_SONDER...  privat   Angebot
# 371288  Mercedes_Benz_A_45_AMG_4Matic_AMG_Speedshift_7...  privat   Angebot
# 371369           Mercedes_ML_350_BlueTEC_4MATIC_7G_TRONIC  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 56      39600     test       coupe                2014  automatik      306
# 148     41900  control         suv                2014  automatik      204
# 275     56900  control   limousine                2015  automatik      326
# 277     48000     test       coupe                2014  automatik      265
# 376     49500     test      cabrio                2013        NaN        0
# ...       ...      ...         ...                 ...        ...      ...
# 371039  44999  control       coupe                2013  automatik      408
# 371196  42000  control   limousine                2012  automatik      564
# 371255  69900     test         suv                2016    manuell      122
# 371288  54000     test   limousine                2015  automatik      360
# 371369  44900     test         suv                2012  automatik      300
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 56        andere      30000                    7   benzin             bmw
# 148          glk      40000                    9   diesel   mercedes_benz
# 275           a6       5000                    7   diesel            audi
# 277       andere      80000                   10   diesel   mercedes_benz
# 376          NaN      10000                    6   benzin  sonstige_autos
# ...          ...        ...                  ...      ...             ...
# 371039  e_klasse      80000                    7   benzin   mercedes_benz
# 371196       NaN      50000                    3   benzin  sonstige_autos
# 371255  defender       5000                    3   diesel      land_rover
# 371288  a_klasse       5000                    2   benzin   mercedes_benz
# 371369  m_klasse     100000                    3   diesel   mercedes_benz
#
#        notRepairedDamage
# 56                  nein
# 148                 nein
# 275                 nein
# 277                 nein
# 376                 nein
# ...                  ...
# 371039              nein
# 371196              nein
# 371255              nein
# 371288              nein
# 371369              nein
#
# [3977 rows x 15 columns]

# %%
base = base.loc[base['price'] < 35000]

# %%
base.shape
# Out:
# (355333, 15)

# %%
base.loc[pd.isnull(base['vehicleType'])]
# Out:
#                                                      name  seller offerType  \
# 0                                              Golf_3_1.6  privat   Angebot
# 16                                            Polo_6n_1_4  privat   Angebot
# 22                          Opel_Meriva_1.Hand_TÜV_3.2018  privat   Angebot
# 26                              Citroen_C4_Grand_Picasso.  privat   Angebot
# 31                           Renault_clio_1.2_TÜV_07/2016  privat   Angebot
# ...                                                   ...     ...       ...
# 371495                                         Opel_Tigra  privat   Angebot
# 371504                                       220_cdi_Benz  privat   Angebot
# 371509  LT_35_DIESEL_Gruene_Plakette....letzte_Gelegen...  privat   Angebot
# 371519  Alfa_Romeo_159_Jtdm_1.9_150_ps_13_600_km_top_voll  privat   Angebot
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 16        300     test         NaN                2016        NaN       60
# 22       2900     test         NaN                2018    manuell       90
# 26       5555  control         NaN                2017    manuell      125
# 31        899  control         NaN                2016    manuell       60
# ...       ...      ...         ...                 ...        ...      ...
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 0           golf     150000                    0   benzin      volkswagen
# 16          polo     150000                    0   benzin      volkswagen
# 22        meriva     150000                    5   benzin            opel
# 26            c4     125000                    4      NaN         citroen
# 31          clio     150000                    6   benzin         renault
# ...          ...        ...                  ...      ...             ...
# 371495       NaN     125000                    3   benzin            opel
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 0                    NaN
# 16                   NaN
# 22                  nein
# 26                  nein
# 31                   NaN
# ...                  ...
# 371495               NaN
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN
#
# [33470 rows x 15 columns]

# %%
base['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine     92943
# kleinwagen    78008
# kombi         65562
# bus           29420
# cabrio        21630
# coupe         17347
# suv           13841
# andere         3112
# Name: count, dtype: int64

# %%
base['vehicleType'].mode()
# Out:
# 0    limousine
# Name: vehicleType, dtype: object

# %%
base.loc[pd.isnull(base['gearbox'])]
# Out:
#                                               name  seller offerType  price  \
# 15                    KA_Lufthansa_Edition_450_VB  privat   Angebot    450
# 16                                     Polo_6n_1_4  privat   Angebot    300
# 32                                Golf_3_....._1.4  privat   Angebot    245
# 37                       Renault_Kangoo_1.9_Diesel  privat   Angebot   1500
# 70           Opel_astra_g_coupe_1.8_liter_benziner  privat   Angebot   1200
# ...                                            ...     ...       ...    ...
# 371443            Touran_2.0__HIGHLINE_LEDER_BEIGE  privat   Angebot   3300
# 371460  Polo_g40_auch_Tausch_vag...no_vr6_gti_1.8t  privat   Angebot   3500
# 371486                                Zu_verkaufen  privat   Angebot    350
# 371495                                  Opel_Tigra  privat   Angebot    180
# 371523                  Suche_t4___vito_ab_6_sitze  privat   Angebot   2200
#
#          abtest vehicleType  yearOfRegistration gearbox  powerPS   model  \
# 15         test  kleinwagen                1910     NaN        0      ka
# 16         test         NaN                2016     NaN       60    polo
# 32         test   limousine                1994     NaN        0    golf
# 37         test         NaN                2016     NaN        0  kangoo
# 70         test       coupe                2001     NaN        0   astra
# ...         ...         ...                 ...     ...      ...     ...
# 371443  control       kombi                2006     NaN        0  touran
# 371460  control         NaN                1995     NaN        0    polo
# 371486  control  kleinwagen                1996     NaN       65   punto
# 371495  control         NaN                1995     NaN        0     NaN
# 371523     test         NaN                2005     NaN        0     NaN
#
#         kilometer  monthOfRegistration fuelType           brand  \
# 15           5000                    0   benzin            ford
# 16         150000                    0   benzin      volkswagen
# 32         150000                    2   benzin      volkswagen
# 37         150000                    1   diesel         renault
# 70         150000                    0      NaN            opel
# ...           ...                  ...      ...             ...
# 371443     150000                    7   diesel      volkswagen
# 371460     150000                    0      NaN      volkswagen
# 371486     150000                    0      NaN            fiat
# 371495     125000                    3   benzin            opel
# 371523      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 15                   NaN
# 16                   NaN
# 32                  nein
# 37                  nein
# 70                   NaN
# ...                  ...
# 371443               NaN
# 371460               NaN
# 371486               NaN
# 371495               NaN
# 371523               NaN
#
# [17089 rows x 15 columns]

# %%
base['gearbox'].value_counts()
# Out:
# gearbox
# manuell      265430
# automatik     72814
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['model'])]
# Out:
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 83                         Bastler_Fahrzeug_mit_Rest_Tuev  privat   Angebot
# 139               Audi_80_5_Zylinder_b4_liebhaberfahrzeug  privat   Angebot
# 156                               POLO_1.2_KILIMA_WIE_NEU  privat   Angebot
# 165                                            is_ales_ok  privat   Angebot
# ...                                                   ...     ...       ...
# 371399         Fiat_Stilo_Abarth_2.4_5zylinder_Seelespeed  privat   Angebot
# 371476                                  ALPINA_D3_Touring  privat   Angebot
# 371495                                         Opel_Tigra  privat   Angebot
# 371509  LT_35_DIESEL_Gruene_Plakette....letzte_Gelegen...  privat   Angebot
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
#
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300     test       coupe                2011    manuell      190
# 83        350  control  kleinwagen                1997    manuell       54
# 139      1450  control   limousine                1992    manuell      136
# 156      6799  control  kleinwagen                2009        NaN       60
# 165       500  control  kleinwagen                1999    manuell        0
# ...       ...      ...         ...                 ...        ...      ...
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
#        model  kilometer  monthOfRegistration fuelType           brand  \
# 1        NaN     125000                    5   diesel            audi
# 83       NaN     150000                    3      NaN            fiat
# 139      NaN     150000                    0      NaN            audi
# 156      NaN      20000                    5   benzin      volkswagen
# 165      NaN     150000                    0   benzin         renault
# ...      ...        ...                  ...      ...             ...
# 371399   NaN      90000                    0   benzin            fiat
# 371476   NaN     150000                    4   diesel  sonstige_autos
# 371495   NaN     125000                    3   benzin            opel
# 371509   NaN     150000                    7      NaN      volkswagen
# 371523   NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 1                     ja
# 83                    ja
# 139                 nein
# 156                 nein
# 165                 nein
# ...                  ...
# 371399                ja
# 371476                ja
# 371495               NaN
# 371509              nein
# 371523               NaN
#
# [17644 rows x 15 columns]

# %%
base['model'].value_counts()
# Out:
# model
# golf          28963
# andere        24812
# 3er           19859
# polo          12604
# corsa         12148
#               ...
# kalina            9
# serie_2           8
# rangerover        6
# serie_3           3
# serie_1           1
# Name: count, Length: 250, dtype: int64
