# %%
import pandas as pd
import tensorflow as tf
import sklearn

# %%
pd.__version__,tf.__version__,sklearn.__version__
# Out:
# ('2.2.3', '2.16.1', '1.5.2')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
base = pd.read_csv('C:/Users/nanojau/OneDrive/Documentos/CURSOS/DeepLearningWithPythonUdemy/autos.csv',encoding='ISO-8859-1')
base
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0       privat   Angebot    480     test         NaN                1993
# 1       privat   Angebot  18300     test       coupe                2011
# 2       privat   Angebot   9800     test         suv                2004
# 3       privat   Angebot   1500     test  kleinwagen                2001
# 4       privat   Angebot   3600     test  kleinwagen                2008
# ...        ...       ...    ...      ...         ...                 ...
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 0         manuell        0         golf     150000                    0
# 1         manuell      190          NaN     125000                    5
# 2       automatik      163        grand     125000                    8
# 3         manuell       75         golf     150000                    6
# 4         manuell       69        fabia      90000                    7
# ...           ...      ...          ...        ...                  ...
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage          dateCreated  \
# 0        benzin      volkswagen               NaN  2016-03-24 00:00:00
# 1        diesel            audi                ja  2016-03-24 00:00:00
# 2        diesel            jeep               NaN  2016-03-14 00:00:00
# 3        benzin      volkswagen              nein  2016-03-17 00:00:00
# 4        diesel           skoda              nein  2016-03-31 00:00:00
# ...         ...             ...               ...                  ...
# 371523      NaN  sonstige_autos               NaN  2016-03-14 00:00:00
# 371524   benzin           smart              nein  2016-03-05 00:00:00
# 371525   diesel      volkswagen              nein  2016-03-19 00:00:00
# 371526   diesel      volkswagen               NaN  2016-03-20 00:00:00
# 371527   benzin             bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 0                  0       70435  2016-04-07 03:16:57
# 1                  0       66954  2016-04-07 01:46:50
# 2                  0       90480  2016-04-05 12:47:46
# 3                  0       91074  2016-03-17 17:40:17
# 4                  0       60437  2016-04-06 10:17:21
# ...              ...         ...                  ...
# 371523             0       39576  2016-04-06 00:46:52
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371526             0       40764  2016-03-24 12:45:21
# 371527             0       73326  2016-03-22 03:17:10
#
# [371528 rows x 20 columns]

# %%
base = base.drop('dateCrawled', axis = 1)
base = base.drop('dateCreated', axis = 1)
base = base.drop('nrOfPictures', axis = 1)
base = base.drop('postalCode', axis = 1)
base = base.drop('lastSeen', axis = 1)
base = base.drop('name', axis = 1)
base = base.drop('offerType', axis = 1)
base = base.drop('seller', axis = 1)
base
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 1       18300     test       coupe                2011    manuell      190
# 2        9800     test         suv                2004  automatik      163
# 3        1500     test  kleinwagen                2001    manuell       75
# 4        3600     test  kleinwagen                2008    manuell       69
# ...       ...      ...         ...                 ...        ...      ...
# 371523   2200     test         NaN                2005        NaN        0
# 371524   1199     test      cabrio                2000  automatik      101
# 371525   9200     test         bus                1996    manuell      102
# 371526   3400     test       kombi                2002    manuell      100
# 371527  28990  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1               NaN     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523          NaN      20000                    1      NaN  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                    NaN
# 1                     ja
# 2                    NaN
# 3                   nein
# 4                   nein
# ...                  ...
# 371523               NaN
# 371524              nein
# 371525              nein
# 371526               NaN
# 371527              nein
#
# [371528 rows x 12 columns]

# %%
base.loc[base['price'] <=10]
# Out:
#         price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 7           0     test   limousine                1980  manuell       50
# 40          0     test         NaN                1990      NaN        0
# 60          1  control         suv                1994  manuell      286
# 91          1  control   limousine                1995  manuell      113
# 115         0     test         NaN                2017  manuell        0
# ...       ...      ...         ...                 ...      ...      ...
# 371356      0  control         NaN                2000  manuell       65
# 371392      0     test  kleinwagen                2002  manuell       60
# 371402      0  control  kleinwagen                1999  manuell       53
# 371431      0  control  kleinwagen                1999  manuell       37
# 371522      0  control         NaN                2005  manuell        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 7         andere      40000                    7   benzin      volkswagen
# 40         corsa     150000                    1   benzin            opel
# 60           NaN     150000                   11      NaN  sonstige_autos
# 91      e_klasse     150000                    4   diesel   mercedes_benz
# 115         golf       5000                   12   benzin      volkswagen
# ...          ...        ...                  ...      ...             ...
# 371356     corsa     150000                    0      NaN            opel
# 371392    fiesta     150000                    3   benzin            ford
# 371402     swift     150000                    3   benzin          suzuki
# 371431     arosa     150000                    7   benzin            seat
# 371522      colt     150000                    7   benzin      mitsubishi
#
#        notRepairedDamage
# 7                   nein
# 40                   NaN
# 60                   NaN
# 91                  nein
# 115                  NaN
# ...                  ...
# 371356                ja
# 371392               NaN
# 371402               NaN
# 371431                ja
# 371522                ja
#
# [12118 rows x 12 columns]

# %%
base['price'].mean()
# Out:
# 17295.14186548524

# %%
base = base[base['price'] > 10]

# %%
base.shape
# Out:
# (359410, 12)

# %%
base.loc[base['price'] > 350000]
# Out:
#            price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 1846      579000  control       coupe                1980  manuell      277
# 10649     420000  control       coupe                2004  manuell      483
# 14663   11111111  control       coupe                2003  manuell       64
# 16889    1000000  control       kombi                1998      NaN        0
# 20143    1250000     test       coupe                2016  manuell      500
# ...          ...      ...         ...                 ...      ...      ...
# 364171   3890000     test       coupe                2006      NaN      799
# 365461    599000  control       coupe                1980  manuell      377
# 366653  99999999  control      cabrio                1996  manuell      192
# 366861   3895000     test       coupe                2006      NaN      799
# 367041   1600000     test       coupe                2005      NaN      625
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 1846    andere      20000                   12   benzin             bmw
# 10649      911      50000                    4   benzin         porsche
# 14663     polo     150000                    2   benzin      volkswagen
# 16889   mondeo     150000                    0   benzin            ford
# 20143      911       5000                    3   benzin         porsche
# ...        ...        ...                  ...      ...             ...
# 364171     NaN       5000                    7      NaN  sonstige_autos
# 365461  andere       5000                    3   benzin             bmw
# 366653     3er     150000                    0      NaN             bmw
# 366861     NaN       5000                    4   benzin  sonstige_autos
# 367041     NaN      10000                    4   benzin  sonstige_autos
#
#        notRepairedDamage
# 1846                nein
# 10649               nein
# 14663                NaN
# 16889                 ja
# 20143               nein
# ...                  ...
# 364171              nein
# 365461              nein
# 366653               NaN
# 366861              nein
# 367041              nein
#
# [115 rows x 12 columns]

# %%
base = base.loc[base['price'] < 350000]

# %%
base.shape
# Out:
# (359291, 12)

# %%
base.loc[pd.isnull(base['vehicleType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 16        300     test         NaN                2016        NaN       60
# 22       2900     test         NaN                2018    manuell       90
# 26       5555  control         NaN                2017    manuell      125
# 31        899  control         NaN                2016    manuell       60
# ...       ...      ...         ...                 ...        ...      ...
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 0           golf     150000                    0   benzin      volkswagen
# 16          polo     150000                    0   benzin      volkswagen
# 22        meriva     150000                    5   benzin            opel
# 26            c4     125000                    4      NaN         citroen
# 31          clio     150000                    6   benzin         renault
# ...          ...        ...                  ...      ...             ...
# 371495       NaN     125000                    3   benzin            opel
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 0                    NaN
# 16                   NaN
# 22                  nein
# 26                  nein
# 31                   NaN
# ...                  ...
# 371495               NaN
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN
#
# [33546 rows x 12 columns]

# %%
base['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine     93614
# kleinwagen    78014
# kombi         65921
# bus           29699
# cabrio        22509
# coupe         18386
# suv           14477
# andere         3125
# Name: count, dtype: int64

# %%
base['vehicleType'].mode()
# Out:
# 0    limousine
# Name: vehicleType, dtype: object

# %%
base.loc[pd.isnull(base['gearbox'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 15        450     test  kleinwagen                1910     NaN        0
# 16        300     test         NaN                2016     NaN       60
# 32        245     test   limousine                1994     NaN        0
# 37       1500     test         NaN                2016     NaN        0
# 70       1200     test       coupe                2001     NaN        0
# ...       ...      ...         ...                 ...     ...      ...
# 371443   3300  control       kombi                2006     NaN        0
# 371460   3500  control         NaN                1995     NaN        0
# 371486    350  control  kleinwagen                1996     NaN       65
# 371495    180  control         NaN                1995     NaN        0
# 371523   2200     test         NaN                2005     NaN        0
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 15          ka       5000                    0   benzin            ford
# 16        polo     150000                    0   benzin      volkswagen
# 32        golf     150000                    2   benzin      volkswagen
# 37      kangoo     150000                    1   diesel         renault
# 70       astra     150000                    0      NaN            opel
# ...        ...        ...                  ...      ...             ...
# 371443  touran     150000                    7   diesel      volkswagen
# 371460    polo     150000                    0      NaN      volkswagen
# 371486   punto     150000                    0      NaN            fiat
# 371495     NaN     125000                    3   benzin            opel
# 371523     NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 15                   NaN
# 16                   NaN
# 32                  nein
# 37                  nein
# 70                   NaN
# ...                  ...
# 371443               NaN
# 371460               NaN
# 371486               NaN
# 371495               NaN
# 371523               NaN
#
# [17236 rows x 12 columns]

# %%
base['gearbox'].value_counts()
# Out:
# gearbox
# manuell      266547
# automatik     75508
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['model'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300     test       coupe                2011    manuell      190
# 83        350  control  kleinwagen                1997    manuell       54
# 139      1450  control   limousine                1992    manuell      136
# 156      6799  control  kleinwagen                2009        NaN       60
# 165       500  control  kleinwagen                1999    manuell        0
# ...       ...      ...         ...                 ...        ...      ...
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
#        model  kilometer  monthOfRegistration fuelType           brand  \
# 1        NaN     125000                    5   diesel            audi
# 83       NaN     150000                    3      NaN            fiat
# 139      NaN     150000                    0      NaN            audi
# 156      NaN      20000                    5   benzin      volkswagen
# 165      NaN     150000                    0   benzin         renault
# ...      ...        ...                  ...      ...             ...
# 371399   NaN      90000                    0   benzin            fiat
# 371476   NaN     150000                    4   diesel  sonstige_autos
# 371495   NaN     125000                    3   benzin            opel
# 371509   NaN     150000                    7      NaN      volkswagen
# 371523   NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 1                     ja
# 83                    ja
# 139                 nein
# 156                 nein
# 165                 nein
# ...                  ...
# 371399                ja
# 371476                ja
# 371495               NaN
# 371509              nein
# 371523               NaN
#
# [17967 rows x 12 columns]

# %%
base['model'].value_counts()
# Out:
# model
# golf               28989
# andere             25560
# 3er                19905
# polo               12604
# corsa              12149
#                    ...
# serie_2                8
# rangerover             6
# serie_3                3
# serie_1                1
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
base.loc[pd.isnull(base['notRepairedDamage'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 2        9800     test         suv                2004  automatik      163
# 8       14500  control         bus                2014    manuell      125
# 9         999     test  kleinwagen                1998    manuell      101
# 12        999  control       kombi                1995    manuell      115
# ...       ...      ...         ...                 ...        ...      ...
# 371507   5999     test       kombi                2005    manuell      140
# 371514    999  control      cabrio                2000    manuell       95
# 371515   1690     test       kombi                2004    manuell       55
# 371523   2200     test         NaN                2005        NaN        0
# 371526   3400     test       kombi                2002    manuell      100
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 0         golf     150000                    0   benzin      volkswagen
# 2        grand     125000                    8   diesel            jeep
# 8        c_max      30000                    8   benzin            ford
# 9         golf     150000                    0      NaN      volkswagen
# 12      passat     150000                   11   benzin      volkswagen
# ...        ...        ...                  ...      ...             ...
# 371507      a4     150000                    4   diesel            audi
# 371514  megane     150000                    4   benzin         renault
# 371515   fabia     150000                    4   benzin           skoda
# 371523     NaN      20000                    1      NaN  sonstige_autos
# 371526    golf     150000                    6   diesel      volkswagen
#
#        notRepairedDamage
# 0                    NaN
# 2                    NaN
# 8                    NaN
# 9                    NaN
# 12                   NaN
# ...                  ...
# 371507               NaN
# 371514               NaN
# 371515               NaN
# 371523               NaN
# 371526               NaN
#
# [65986 rows x 12 columns]

# %%
base['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# nein    259301
# ja       34004
# Name: count, dtype: int64

# %%
base.loc[pd.isnull(base['fuelType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 9         999     test  kleinwagen                1998    manuell      101
# 13       2500  control       kombi                2004    manuell      131
# 26       5555  control         NaN                2017    manuell      125
# 36       1600  control      andere                1991    manuell       75
# 41       7500  control   limousine                2002  automatik      306
# ...       ...      ...         ...                 ...        ...      ...
# 371496   3850     test      cabrio                2006    manuell      108
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 9           golf     150000                    0      NaN      volkswagen
# 13        passat     150000                    2      NaN      volkswagen
# 26            c4     125000                    4      NaN         citroen
# 36        kadett      70000                    0      NaN            opel
# 41      e_klasse     150000                    4      NaN   mercedes_benz
# ...          ...        ...                  ...      ...             ...
# 371496   2_reihe     125000                    2      NaN         peugeot
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 9                    NaN
# 13                  nein
# 26                  nein
# 36                   NaN
# 41                   NaN
# ...                  ...
# 371496              nein
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN
#
# [29391 rows x 12 columns]

# %%
base['fuelType'].value_counts()
# Out:
# fuelType
# benzin     217582
# diesel     106002
# lpg          5222
# cng           557
# hybrid        271
# andere        165
# elektro       101
# Name: count, dtype: int64

# %%
valores = {'vehicleType':'limousine',
           'gearbox' : 'namuell',
           'model' : 'golf',
           'fuelType' : 'nenzin',
           'notRepairedDamage': 'nein'}

# %%
base = base.fillna(value = valores)
base
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test   limousine                1993    manuell        0
# 1       18300     test       coupe                2011    manuell      190
# 2        9800     test         suv                2004  automatik      163
# 3        1500     test  kleinwagen                2001    manuell       75
# 4        3600     test  kleinwagen                2008    manuell       69
# ...       ...      ...         ...                 ...        ...      ...
# 371523   2200     test   limousine                2005    namuell        0
# 371524   1199     test      cabrio                2000  automatik      101
# 371525   9200     test         bus                1996    manuell      102
# 371526   3400     test       kombi                2002    manuell      100
# 371527  28990  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 0              golf     150000                    0   benzin      volkswagen
# 1              golf     125000                    5   diesel            audi
# 2             grand     125000                    8   diesel            jeep
# 3              golf     150000                    6   benzin      volkswagen
# 4             fabia      90000                    7   diesel           skoda
# ...             ...        ...                  ...      ...             ...
# 371523         golf      20000                    1   nenzin  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 0                   nein
# 1                     ja
# 2                   nein
# 3                   nein
# 4                   nein
# ...                  ...
# 371523              nein
# 371524              nein
# 371525              nein
# 371526              nein
# 371527              nein
#
# [359291 rows x 12 columns]

# %%
base.isnull().sum()
# Out:
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dtype: int64

# %%
base.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
#        'brand', 'notRepairedDamage'],
#       dtype='object')

# %%
x= base.iloc[: , 1:12].values

# %%
y = base.iloc[: , 0].values
y
# Out:
# array([  480, 18300,  9800, ...,  9200,  3400, 28990], dtype=int64)

# %%
base['brand'].value_counts()
# Out:
# brand
# volkswagen        76755
# bmw               38982
# opel              38557
# mercedes_benz     34498
# audi              31884
# ford              24761
# renault           17367
# peugeot           10777
# fiat               9339
# seat               6815
# skoda              5572
# mazda              5529
# smart              5159
# citroen            5038
# nissan             4893
# toyota             4616
# hyundai            3585
# mini               3354
# sonstige_autos     3331
# volvo              3229
# mitsubishi         2956
# honda              2726
# kia                2494
# suzuki             2274
# alfa_romeo         2250
# porsche            2154
# chevrolet          1791
# chrysler           1373
# dacia               889
# jeep                784
# daihatsu            774
# land_rover          759
# subaru              746
# jaguar              603
# daewoo              530
# saab                516
# trabant             489
# lancia              467
# rover               462
# lada                213
# Name: count, dtype: int64

# %%
base.columns
# Out:
# Index(['price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox',
#        'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType',
#        'brand', 'notRepairedDamage'],
#       dtype='object')

# %%
onehotencoder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), [0, 1, 3, 5, 8, 9, 10])], remainder='passthrough')

# %%
X = onehotencoder.fit_transform(x).toarray()
X
# Out:
# array([[0.00e+00, 1.00e+00, 0.00e+00, ..., 0.00e+00, 1.50e+05, 0.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.90e+02, 1.25e+05, 5.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.63e+02, 1.25e+05, 8.00e+00],
#        ...,
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.02e+02, 1.50e+05, 3.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.00e+02, 1.50e+05, 6.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, ..., 3.20e+02, 5.00e+04, 8.00e+00]])

# %%
base.shape
# Out:
# (359291, 12)

# %%
x.shape
# Out:
# (359291, 11)

# %%
regressor = Sequential([
    tf.keras.layers.InputLayer(shape = (318 ,)),
    tf.keras.layers.Dense(units = 158, activation = 'relu'),
    tf.keras.layers.Dense(units = 158, activation = 'relu'),
    tf.keras.layers.Dense(units = 1, activation = 'linear')
])

# %%
regressor.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                │ (None, 158)            │        50,402 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 158)            │        25,122 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │           159 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,683 (295.64 KB)
#  Trainable params: 75,683 (295.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
regressor.compile(loss = 'mean_absolute_error', optimizer = 'adam', metrics = ['mean_absolute_error'])

# %%
regressor.fit(X, y, batch_size = 300, epochs = 100)
# Out:
# Epoch 1/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 4213.6514 - mean_absolute_error: 4213.6514
# Epoch 2/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 3375.4177 - mean_absolute_error: 3375.4177
# Epoch 3/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 3082.6902 - mean_absolute_error: 3082.6902
# Epoch 4/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2937.1338 - mean_absolute_error: 2937.1338
# Epoch 5/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2852.1028 - mean_absolute_error: 2852.1028
# Epoch 6/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2778.0713 - mean_absolute_error: 2778.0713
# Epoch 7/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2734.9944 - mean_absolute_error: 2734.9941
# Epoch 8/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2691.4932 - mean_absolute_error: 2691.4932
# Epoch 9/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2671.9719 - mean_absolute_error: 2671.9719
# Epoch 10/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2630.7905 - mean_absolute_error: 2630.7905
# Epoch 11/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2572.6189 - mean_absolute_error: 2572.6189
# Epoch 12/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2543.2405 - mean_absolute_error: 2543.2405
# Epoch 13/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2541.1968 - mean_absolute_error: 2541.1968
# Epoch 14/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2495.6177 - mean_absolute_error: 2495.6177
# Epoch 15/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2510.7119 - mean_absolute_error: 2510.7119
# Epoch 16/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2470.4041 - mean_absolute_error: 2470.4041
# Epoch 17/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2435.8306 - mean_absolute_error: 2435.8306
# Epoch 18/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2438.3494 - mean_absolute_error: 2438.3494
# Epoch 19/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2424.2163 - mean_absolute_error: 2424.2163
# Epoch 20/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2432.4053 - mean_absolute_error: 2432.4053
# Epoch 21/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2426.5271 - mean_absolute_error: 2426.5273
# Epoch 22/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2418.7847 - mean_absolute_error: 2418.7847
# Epoch 23/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2392.2478 - mean_absolute_error: 2392.2478
# Epoch 24/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2388.9324 - mean_absolute_error: 2388.9324
# Epoch 25/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2400.1155 - mean_absolute_error: 2400.1155
# Epoch 26/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2412.5210 - mean_absolute_error: 2412.5210
# Epoch 27/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2403.8323 - mean_absolute_error: 2403.8323
# Epoch 28/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2377.0291 - mean_absolute_error: 2377.0291
# Epoch 29/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2351.9866 - mean_absolute_error: 2351.9866
# Epoch 30/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2389.7983 - mean_absolute_error: 2389.7983
# Epoch 31/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2359.4924 - mean_absolute_error: 2359.4924
# Epoch 32/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2356.4517 - mean_absolute_error: 2356.4517
# Epoch 33/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2347.5474 - mean_absolute_error: 2347.5474
# Epoch 34/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2359.9902 - mean_absolute_error: 2359.9902
# Epoch 35/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2367.5388 - mean_absolute_error: 2367.5386
# Epoch 36/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2357.9160 - mean_absolute_error: 2357.9160
# Epoch 37/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2350.9380 - mean_absolute_error: 2350.9380
# Epoch 38/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2341.3606 - mean_absolute_error: 2341.3606
# Epoch 39/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2344.3232 - mean_absolute_error: 2344.3235
# Epoch 40/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2338.6311 - mean_absolute_error: 2338.6311
# Epoch 41/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2338.0881 - mean_absolute_error: 2338.0881
# Epoch 42/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2332.0679 - mean_absolute_error: 2332.0679
# Epoch 43/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2344.7896 - mean_absolute_error: 2344.7896
# Epoch 44/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2328.1575 - mean_absolute_error: 2328.1575
# Epoch 45/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2332.8630 - mean_absolute_error: 2332.8630
# Epoch 46/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2334.4802 - mean_absolute_error: 2334.4802
# Epoch 47/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2322.0244 - mean_absolute_error: 2322.0244
# Epoch 48/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2321.4390 - mean_absolute_error: 2321.4390
# Epoch 49/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2329.6440 - mean_absolute_error: 2329.6440
# Epoch 50/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2329.2717 - mean_absolute_error: 2329.2717
# Epoch 51/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2312.0686 - mean_absolute_error: 2312.0686
# Epoch 52/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2314.5134 - mean_absolute_error: 2314.5134
# Epoch 53/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2309.7034 - mean_absolute_error: 2309.7034
# Epoch 54/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2307.4448 - mean_absolute_error: 2307.4448
# Epoch 55/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2316.8118 - mean_absolute_error: 2316.8118
# Epoch 56/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2292.9255 - mean_absolute_error: 2292.9255
# Epoch 57/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2305.1475 - mean_absolute_error: 2305.1475
# Epoch 58/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2288.7888 - mean_absolute_error: 2288.7888
# Epoch 59/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2277.6880 - mean_absolute_error: 2277.6880
# Epoch 60/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2301.6233 - mean_absolute_error: 2301.6233
# Epoch 61/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2290.1387 - mean_absolute_error: 2290.1387
# Epoch 62/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2292.1113 - mean_absolute_error: 2292.1113
# Epoch 63/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2291.6694 - mean_absolute_error: 2291.6694
# Epoch 64/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2292.5679 - mean_absolute_error: 2292.5679
# Epoch 65/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2282.7717 - mean_absolute_error: 2282.7717
# Epoch 66/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2281.4890 - mean_absolute_error: 2281.4890
# Epoch 67/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2287.2380 - mean_absolute_error: 2287.2380
# Epoch 68/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2255.8979 - mean_absolute_error: 2255.8977
# Epoch 69/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2283.3223 - mean_absolute_error: 2283.3223
# Epoch 70/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2269.2708 - mean_absolute_error: 2269.2710
# Epoch 71/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2290.8745 - mean_absolute_error: 2290.8745
# Epoch 72/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2269.3582 - mean_absolute_error: 2269.3582
# Epoch 73/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2281.1116 - mean_absolute_error: 2281.1116
# Epoch 74/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2257.0984 - mean_absolute_error: 2257.0984
# Epoch 75/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2292.8291 - mean_absolute_error: 2292.8291
# Epoch 76/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2283.3323 - mean_absolute_error: 2283.3323
# Epoch 77/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2271.7708 - mean_absolute_error: 2271.7708
# Epoch 78/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2266.8994 - mean_absolute_error: 2266.8994
# Epoch 79/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2279.3848 - mean_absolute_error: 2279.3848
# Epoch 80/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2258.3997 - mean_absolute_error: 2258.3997
# Epoch 81/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2280.7009 - mean_absolute_error: 2280.7009
# Epoch 82/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2261.9304 - mean_absolute_error: 2261.9304
# Epoch 83/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2259.4121 - mean_absolute_error: 2259.4119
# Epoch 84/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2284.8450 - mean_absolute_error: 2284.8450
# Epoch 85/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2270.2544 - mean_absolute_error: 2270.2544
# Epoch 86/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2256.8853 - mean_absolute_error: 2256.8853
# Epoch 87/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2255.8687 - mean_absolute_error: 2255.8687
# Epoch 88/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2279.3904 - mean_absolute_error: 2279.3904
# Epoch 89/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2239.7576 - mean_absolute_error: 2239.7573
# Epoch 90/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2268.0181 - mean_absolute_error: 2268.0181
# Epoch 91/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2240.8616 - mean_absolute_error: 2240.8616
# Epoch 92/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2234.7654 - mean_absolute_error: 2234.7656
# Epoch 93/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2248.3242 - mean_absolute_error: 2248.3242
# Epoch 94/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2254.3066 - mean_absolute_error: 2254.3066
# Epoch 95/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2250.1499 - mean_absolute_error: 2250.1499
# Epoch 96/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 2239.3860 - mean_absolute_error: 2239.3860
# Epoch 97/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2245.7681 - mean_absolute_error: 2245.7681
# Epoch 98/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2245.5747 - mean_absolute_error: 2245.5747
# Epoch 99/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2235.6460 - mean_absolute_error: 2235.6460
# Epoch 100/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 2240.9421 - mean_absolute_error: 2240.9421

# %%
X.shape
# Out:
# (359291, 318)

# %%
previsoes = regressor.predict(X)
# Out:
# 11228/11228 ━━━━━━━━━━━━━━━━━━━━ 10s 922us/step

# %%
previsoes
# Out:
# array([[  996.71716],
#        [ 8869.639  ],
#        [10328.978  ],
#        ...,
#        [ 4802.2065 ],
#        [ 2883.7031 ],
#        [24897.562  ]], dtype=float32)

# %%
y
# Out:
# array([  480, 18300,  9800, ...,  9200,  3400, 28990], dtype=int64)

# %%
y.mean()
# Out:
# 5916.833945186492

# %%
previsoes.mean()
# Out:
# 4721.379
